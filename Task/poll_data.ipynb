# %%
import numpy as np
import pandas as pd

# %%
poll_data = pd.read_excel('AC105_2014.xlsx')

# %%
poll_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Polling Station No.                  237 non-null    object
#  1   ELANGOVAN.E.V.K.S                    237 non-null    object
#  2   GURUSAMY.N                           237 non-null    object
#  3   SATHYABAMA.V                         237 non-null    object
#  4   SUBBARAYAN.K                         237 non-null    object
#  5   SENTHILNATHAN.M                      237 non-null    object
#  6   DINESHKUMAR.N                        237 non-null    object
#  7   GOPALSAMY.R                          237 non-null    object
#  8   CHAKRAVARTHI RAJA GOPALA KRISHNAN.R  237 non-null    object
#  9   SIVAKUMAR.N                          237 non-null    object
#  10  MURUGESAN.R                          237 non-null    object
# ...

# %%
poll_data.shape
# Out:
# (237, 28)

# %%
poll_data.head()
# Out:
#    Polling Station No.         ELANGOVAN.E.V.K.S  ... SHEIKDAVOOD.A.M  NOTA
# 0  Polling Station No.  INDIAN NATIONAL CONGRESS  ...     INDEPENDENT  NOTA
# 1                    1                        19  ...               1     2
# 2                    2                        39  ...               3     3
# 3                    3                         9  ...               0     4
# 4                    4                        18  ...               3    10
#
# [5 rows x 28 columns]

# %%
poll_data.columns
# Out:
# Index(['Polling Station No.', 'ELANGOVAN.E.V.K.S', 'GURUSAMY.N',
#        'SATHYABAMA.V', 'SUBBARAYAN.K', 'SENTHILNATHAN.M', 'DINESHKUMAR.N',
#        'GOPALSAMY.R', 'CHAKRAVARTHI RAJA GOPALA KRISHNAN.R', 'SIVAKUMAR.N',
#        'MURUGESAN.R', 'LAXMI.J', 'SATHYABAMA.R', 'SATHYABHAMA.R',
#        'SENTHILKUMAR.K', 'SENTHIL KUMAR.T.S', 'SELVABOOPATHI.P',
#        'DINESHKUMAR.S.K', 'NANDHAKUMAR.R', 'PALANISAMY.M',
#        'BALASUBRAMANIYAN. P', 'PONNUSAMY.A', 'MURUGAN.R.R', 'MOGHEETH KHAN.A',
#        'RAJENDRAN.M', 'PASTOR JAMES.A', 'SHEIKDAVOOD.A.M', 'NOTA'],
#       dtype='object')

# %%
poll_data.rename(columns={'Polling Station No.':'Candidate'}, inplace=True)

# %%
poll_data.set_index('Candidate')
# Out:
#                             ELANGOVAN.E.V.K.S  ...  NOTA
# Candidate                                      ...
# Polling Station No.  INDIAN NATIONAL CONGRESS  ...  NOTA
# 1                                          19  ...     2
# 2                                          39  ...     3
# 3                                           9  ...     4
# 4                                          18  ...    10
# ...                                       ...  ...   ...
# 232                                        16  ...     4
# 233                                        21  ...    11
# 234                                        24  ...     2
# 235                                        18  ...     5
# 236                                       136  ...    19
#
# [237 rows x 27 columns]

# %%
poll_data.shape
# Out:
# (237, 28)

# %%
poll_data = poll_data.transpose()

# %%
poll_data.head()
# Out:
#                                                         0    1    ...  235  236
# Candidate                               Polling Station No.    1  ...  235  236
# ELANGOVAN.E.V.K.S                  INDIAN NATIONAL CONGRESS   19  ...   18  136
# GURUSAMY.N                              BAHUJAN SAMAJ PARTY   14  ...    4    8
# SATHYABAMA.V       ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM  335  ...  296  441
# SUBBARAYAN.K                       COMMUNIST PARTY OF INDIA   12  ...    2    2
#
# [5 rows x 237 columns]

# %%
new_header = poll_data.iloc[0] 

poll_data = poll_data[1:] 

poll_data.columns = new_header

# %%
poll_data.head()
# Out:
# Candidate                               Polling Station No.    1  ...  235  236
# ELANGOVAN.E.V.K.S                  INDIAN NATIONAL CONGRESS   19  ...   18  136
# GURUSAMY.N                              BAHUJAN SAMAJ PARTY   14  ...    4    8
# SATHYABAMA.V       ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM  335  ...  296  441
# SUBBARAYAN.K                       COMMUNIST PARTY OF INDIA   12  ...    2    2
# SENTHILNATHAN.M                   DRAVIDA MUNNETRA KAZHAGAM  337  ...  139  233
#
# [5 rows x 237 columns]

# %%
poll_data.shape
# Out:
# (27, 237)

# %%
poll_data.to_excel('poll_data_lform.xlsx')

# %%
poll_data.reset_index(inplace=True)

# %%
poll_data.rename(columns={'index':'candidate'}, inplace=True)

# %%
poll_data.head()
# Out:
# Candidate          candidate  ...  236
# 0          ELANGOVAN.E.V.K.S  ...  136
# 1                 GURUSAMY.N  ...    8
# 2               SATHYABAMA.V  ...  441
# 3               SUBBARAYAN.K  ...    2
# 4            SENTHILNATHAN.M  ...  233
#
# [5 rows x 238 columns]

# %%
#poll_data.drop('Candidate',axis=1,inplace = True)

# %%
poll_data.head()
# Out:
# Candidate          candidate  ...  236
# 0          ELANGOVAN.E.V.K.S  ...  136
# 1                 GURUSAMY.N  ...    8
# 2               SATHYABAMA.V  ...  441
# 3               SUBBARAYAN.K  ...    2
# 4            SENTHILNATHAN.M  ...  233
#
# [5 rows x 238 columns]

# %%
poll_data.rename_axis(None, inplace=True)

# %%
poll_data.columns
# Out:
# Index([          'candidate', 'Polling Station No.',                     1,
#                            2,                     3,                     4,
#                            5,                     6,                     7,
#                            8,
#        ...
#                          227,                   228,                   229,
#                          230,                   231,                   232,
#                          233,                   234,                   235,
#                          236],
#       dtype='object', name='Candidate', length=238)

# %%
poll_data.head()
# Out:
# Candidate          candidate  ...  236
# 0          ELANGOVAN.E.V.K.S  ...  136
# 1                 GURUSAMY.N  ...    8
# 2               SATHYABAMA.V  ...  441
# 3               SUBBARAYAN.K  ...    2
# 4            SENTHILNATHAN.M  ...  233
#
# [5 rows x 238 columns]

# %%
poll_data.rename(columns={'Polling Station No.':'party'}, inplace=True)

# %%
poll_data.head()
# Out:
# Candidate          candidate  ...  236
# 0          ELANGOVAN.E.V.K.S  ...  136
# 1                 GURUSAMY.N  ...    8
# 2               SATHYABAMA.V  ...  441
# 3               SUBBARAYAN.K  ...    2
# 4            SENTHILNATHAN.M  ...  233
#
# [5 rows x 238 columns]

# %%
poll_data2 = pd.melt(poll_data,id_vars=['candidate','party'])

# %%
poll_data2.head(30)
# Out:
#                               candidate  ... value
# 0                     ELANGOVAN.E.V.K.S  ...    19
# 1                            GURUSAMY.N  ...    14
# 2                          SATHYABAMA.V  ...   335
# 3                          SUBBARAYAN.K  ...    12
# 4                       SENTHILNATHAN.M  ...   337
# 5                         DINESHKUMAR.N  ...    45
# 6                           GOPALSAMY.R  ...     2
# 7   CHAKRAVARTHI RAJA GOPALA KRISHNAN.R  ...     3
# 8                           SIVAKUMAR.N  ...     1
# 9                           MURUGESAN.R  ...     5
# 10                              LAXMI.J  ...     3
# 11                         SATHYABAMA.R  ...     8
# 12                        SATHYABHAMA.R  ...     1
# 13                       SENTHILKUMAR.K  ...     6
# 14                    SENTHIL KUMAR.T.S  ...     8
# 15                      SELVABOOPATHI.P  ...    11
# 16                      DINESHKUMAR.S.K  ...     2
# ...

# %%
poll_data2.rename(columns={'Candidate':'polling Station No.','value':'votes'}, inplace=True)

# %%
poll_data2.groupby('candidate')['votes'].sum()
# Out:
# candidate
# BALASUBRAMANIYAN. P                      182
# CHAKRAVARTHI RAJA GOPALA KRISHNAN.R      398
# DINESHKUMAR.N                          36000
# DINESHKUMAR.S.K                          275
# ELANGOVAN.E.V.K.S                       8628
# GOPALSAMY.R                              402
# GURUSAMY.N                               933
# LAXMI.J                                  189
# MOGHEETH KHAN.A                          204
# MURUGAN.R.R                             1071
# MURUGESAN.R                              408
# NANDHAKUMAR.R                            168
# NOTA                                    1854
# PALANISAMY.M                             774
# PASTOR JAMES.A                           245
# PONNUSAMY.A                              222
# RAJENDRAN.M                              414
# SATHYABAMA.R                             221
# SATHYABAMA.V                           65256
# SATHYABHAMA.R                            232
# SELVABOOPATHI.P                          934
# ...

# %%
poll_data2.set_index('candidate',drop=True,inplace=True)

# %%
poll_data2.head()
# Out:
#                                                       party  ... votes
# candidate                                                    ...
# ELANGOVAN.E.V.K.S                  INDIAN NATIONAL CONGRESS  ...    19
# GURUSAMY.N                              BAHUJAN SAMAJ PARTY  ...    14
# SATHYABAMA.V       ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM  ...   335
# SUBBARAYAN.K                       COMMUNIST PARTY OF INDIA  ...    12
# SENTHILNATHAN.M                   DRAVIDA MUNNETRA KAZHAGAM  ...   337
#
# [5 rows x 3 columns]

# %%
poll_data2.to_excel("poll_data_lform2.xlsx")
